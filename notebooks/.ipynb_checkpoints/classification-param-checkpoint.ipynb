# %%
print("hallo")
# Out:
# hallo

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.optimizers import Adam

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import sys

import matplotlib.pyplot as plt

# %%
#folder_repository = "/Users/harun/Desktop/Uni/4. Semester/Data Mining/DataMining_TeamA"
folder_repository = "C:/Users/andre/Documents/Github/DataMining_TeamA"

folder_data = f"{folder_repository}/resources/data_classification"
folder_labels = f"{folder_repository}/resources/data_classification/labels"
folder_output = f"{folder_repository}/output/classification"

# %%
def accuracy(Y_test, predictions, dataset):
    # extract neurons with most activation
    predicted_classes = []
    for prediction in predictions:
        predicted_classes.append(np.argmax(prediction))

    accuracy = accuracy_score(Y_test, predicted_classes)
    print(f"{dataset}: {accuracy}")

# %%
def model_arch(testsplit: float, activation, neurons: int, learn_rate_adam: float, epochs: int, batch_size: int, metrics: list):
    datasets = ['x0_with_labels.csv', 'x1_with_labels.csv', 'x2_with_labels.csv']
    for dataset in datasets:
        data = pd.read_csv(f"{folder_data}/{dataset}")

        # Split datasets into train and test
        X_train, X_test, Y_train, Y_test = train_test_split(data.iloc[:, :-1], data.iloc[:, -1], test_size=testsplit, shuffle = True)

        # labels are intepretated as ordinal, so the model need to know, that the labels are categories
        Y_train_encoded = to_categorical(Y_train)
        Y_test_encoded = to_categorical(Y_test)

        # Create NN model
        model = Sequential()
        
        model.add(Dense(neurons, activation=activation))
        model.add(Dense(neurons, activation=activation))
        model.add(Dense(30, activation='softmax'))
        
        optimizer=Adam(learning_rate=learn_rate_adam)

        # compile model
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=metrics)

        # train model
        model.fit(X_train, Y_train_encoded, epochs=epochs, batch_size=batch_size, verbose=0)
        
        predictions = model.predict(X_test)
        accuracy(Y_test, predictions, dataset[:2])
        #feature_importance(model)

# %%
for a in ['relu', 'sigmoid', 'tanh', 'linear']:
    print(a)
    print("&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&")
    model_arch(testsplit=0.3, activation=a, neurons=64, learn_rate_adam=0.001, epochs=10, batch_size=30, metrics=['accuracy'])
# Out:
# relu
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Epoch 1/10
# 684/684 [==============================] - 2s 1ms/step - loss: 0.7783 - accuracy: 0.8613
# Epoch 2/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.9740
# Epoch 3/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1487 - accuracy: 0.9751
# Epoch 4/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1291 - accuracy: 0.9769
# Epoch 5/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1145 - accuracy: 0.9787
# Epoch 6/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1020 - accuracy: 0.9814
# Epoch 7/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0915 - accuracy: 0.9830
# Epoch 8/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0830 - accuracy: 0.9843
# Epoch 9/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0766 - accuracy: 0.9861
# Epoch 10/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0702 - accuracy: 0.9874
# 275/275 [==============================] - 0s 968us/step
# x0: 0.9805394332536702
# Epoch 1/10
# 38/38 [==============================] - 1s 2ms/step - loss: 3.3190 - accuracy: 0.1309
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8695 - accuracy: 0.5431
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 2.1103 - accuracy: 0.6696
# Epoch 4/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3137 - accuracy: 0.8638
# Epoch 5/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7837 - accuracy: 0.9332
# Epoch 6/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.5027 - accuracy: 0.9552
# Epoch 7/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.9631
# Epoch 8/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.3050 - accuracy: 0.9657
# Epoch 9/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.2705 - accuracy: 0.9666
# Epoch 10/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.2462 - accuracy: 0.9692
# 16/16 [==============================] - 0s 1ms/step
# x1: 0.9856850715746421
# Epoch 1/10
# 38/38 [==============================] - 1s 2ms/step - loss: 3.3346 - accuracy: 0.0808
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.0665 - accuracy: 0.2634
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 2.6545 - accuracy: 0.3977
# Epoch 4/10
# 38/38 [==============================] - 0s 1ms/step - loss: 2.1413 - accuracy: 0.5505
# Epoch 5/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.6939 - accuracy: 0.6936
# Epoch 6/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3883 - accuracy: 0.7665
# Epoch 7/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1947 - accuracy: 0.7928
# Epoch 8/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.0668 - accuracy: 0.8060
# Epoch 9/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.9773 - accuracy: 0.8104
# Epoch 10/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.9034 - accuracy: 0.8174
# 16/16 [==============================] - 0s 1ms/step
# x2: 0.8016359918200409
# sigmoid
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Epoch 1/10
# 684/684 [==============================] - 2s 1ms/step - loss: 2.9500 - accuracy: 0.2857
# Epoch 2/10
# 684/684 [==============================] - 1s 1ms/step - loss: 1.1190 - accuracy: 0.8987
# Epoch 3/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.4062 - accuracy: 0.9723
# Epoch 4/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2686 - accuracy: 0.9724
# Epoch 5/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2245 - accuracy: 0.9726
# Epoch 6/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2010 - accuracy: 0.9731
# Epoch 7/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.9735
# Epoch 8/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1726 - accuracy: 0.9738
# Epoch 9/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1626 - accuracy: 0.9746
# Epoch 10/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1544 - accuracy: 0.9748
# 275/275 [==============================] - 0s 1ms/step
# x0: 0.971435074541937
# Epoch 1/10
# 38/38 [==============================] - 1s 2ms/step - loss: 3.4539 - accuracy: 0.0431
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3551 - accuracy: 0.0527
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3337 - accuracy: 0.0694
# Epoch 4/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3124 - accuracy: 0.1028
# Epoch 5/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.2852 - accuracy: 0.1318
# Epoch 6/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.2546 - accuracy: 0.1494
# Epoch 7/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.2124 - accuracy: 0.1248
# Epoch 8/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.1594 - accuracy: 0.2399
# Epoch 9/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.0902 - accuracy: 0.2583
# Epoch 10/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.0019 - accuracy: 0.2636
# 16/16 [==============================] - 0s 1ms/step
# x1: 0.28016359918200406
# Epoch 1/10
# 38/38 [==============================] - 1s 2ms/step - loss: 3.4518 - accuracy: 0.0342
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3719 - accuracy: 0.0500
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3587 - accuracy: 0.0518
# Epoch 4/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.3434 - accuracy: 0.0527
# Epoch 5/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3306 - accuracy: 0.0518
# Epoch 6/10
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3136 - accuracy: 0.0641
# Epoch 7/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.2890 - accuracy: 0.1466
# Epoch 8/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.2643 - accuracy: 0.1387
# Epoch 9/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.2260 - accuracy: 0.2432
# Epoch 10/10
# 38/38 [==============================] - 0s 1ms/step - loss: 3.1826 - accuracy: 0.2555
# 16/16 [==============================] - 0s 1ms/step
# x2: 0.294478527607362
# tanh
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Epoch 1/10
# 684/684 [==============================] - 2s 1ms/step - loss: 0.7225 - accuracy: 0.9018
# Epoch 2/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1957 - accuracy: 0.9725
# Epoch 3/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1678 - accuracy: 0.9740
# Epoch 4/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1494 - accuracy: 0.9750
# Epoch 5/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1337 - accuracy: 0.9764
# Epoch 6/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1203 - accuracy: 0.9782
# Epoch 7/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.1089 - accuracy: 0.9801
# Epoch 8/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0991 - accuracy: 0.9821
# Epoch 9/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0912 - accuracy: 0.9836
# Epoch 10/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.0841 - accuracy: 0.9850
# 275/275 [==============================] - 0s 1ms/step
# x0: 0.9823603049960169
# Epoch 1/10
# 38/38 [==============================] - 1s 2ms/step - loss: 3.1504 - accuracy: 0.2654
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4631 - accuracy: 0.6863
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7549 - accuracy: 0.8260
# Epoch 4/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1781 - accuracy: 0.8866
# Epoch 5/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7966 - accuracy: 0.9473
# Epoch 6/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5681 - accuracy: 0.9666
# Epoch 7/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4337 - accuracy: 0.9684
# Epoch 8/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3552 - accuracy: 0.9684
# Epoch 9/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3081 - accuracy: 0.9684
# Epoch 10/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2775 - accuracy: 0.9684
# 16/16 [==============================] - 0s 1ms/step
# x1: 0.983640081799591
# Epoch 1/10
# 38/38 [==============================] - 1s 1ms/step - loss: 3.2105 - accuracy: 0.1580
# Epoch 2/10
# 38/38 [==============================] - 0s 1ms/step - loss: 2.7574 - accuracy: 0.4214
# Epoch 3/10
# 38/38 [==============================] - 0s 1ms/step - loss: 2.3287 - accuracy: 0.6286
# Epoch 4/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9461 - accuracy: 0.7068
# Epoch 5/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.6541 - accuracy: 0.7366
# Epoch 6/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.4541 - accuracy: 0.7524
# Epoch 7/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.3118 - accuracy: 0.7621
# Epoch 8/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.2121 - accuracy: 0.7779
# Epoch 9/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.1383 - accuracy: 0.7919
# Epoch 10/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.0771 - accuracy: 0.7989
# 16/16 [==============================] - 0s 1ms/step
# x2: 0.7811860940695297
# linear
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# Epoch 1/10
# 684/684 [==============================] - 2s 1ms/step - loss: 0.7740 - accuracy: 0.8867
# Epoch 2/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2416 - accuracy: 0.9718
# Epoch 3/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2244 - accuracy: 0.9722
# Epoch 4/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2185 - accuracy: 0.9726
# Epoch 5/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2247 - accuracy: 0.9718
# Epoch 6/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2281 - accuracy: 0.9711
# Epoch 7/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2364 - accuracy: 0.9706
# Epoch 8/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2173 - accuracy: 0.9734
# Epoch 9/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2122 - accuracy: 0.9735
# Epoch 10/10
# 684/684 [==============================] - 1s 1ms/step - loss: 0.2093 - accuracy: 0.9736
# 275/275 [==============================] - 0s 939us/step
# x0: 0.9723455104131102
# Epoch 1/10
# 38/38 [==============================] - 1s 2ms/step - loss: 3.0505 - accuracy: 0.2425
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2333 - accuracy: 0.5589
# Epoch 3/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4548 - accuracy: 0.7663
# Epoch 4/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.8704 - accuracy: 0.9192
# Epoch 5/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5381 - accuracy: 0.9649
# Epoch 6/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.9736
# Epoch 7/10
# 38/38 [==============================] - 0s 1ms/step - loss: 0.2803 - accuracy: 0.9754
# Epoch 8/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2287 - accuracy: 0.9763
# Epoch 9/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2002 - accuracy: 0.9763
# Epoch 10/10
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1816 - accuracy: 0.9763
# 16/16 [==============================] - 0s 1ms/step
# x1: 0.9652351738241309
# Epoch 1/10
# 38/38 [==============================] - 1s 1ms/step - loss: 3.2266 - accuracy: 0.1493
# Epoch 2/10
# 38/38 [==============================] - 0s 2ms/step - loss: 2.7701 - accuracy: 0.3924
# Epoch 3/10
# 38/38 [==============================] - 0s 1ms/step - loss: 2.3220 - accuracy: 0.5716
# Epoch 4/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.9056 - accuracy: 0.6795
# Epoch 5/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.5981 - accuracy: 0.7507
# Epoch 6/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.3994 - accuracy: 0.7770
# Epoch 7/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.2707 - accuracy: 0.7831
# Epoch 8/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1905 - accuracy: 0.7893
# Epoch 9/10
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1321 - accuracy: 0.7963
# Epoch 10/10
# 38/38 [==============================] - 0s 1ms/step - loss: 1.0877 - accuracy: 0.7954
# 16/16 [==============================] - 0s 1ms/step
# x2: 0.7955010224948875
